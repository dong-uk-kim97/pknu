# %%
import pandas as pd 
import numpy as np
import matplotlib as plt
import seaborn as sns

plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['axes.unicode_minus'] =False
plt.rcParams['figure.figsize'] = (20,10)

sns.set(font="Malgun Gothic", 
        rc={"axes.unicode_minus":False}, # 마이너스 부호 깨짐 현상 해결
        style='whitegrid')

# %%
train = pd.read_csv('./origin/train.csv')
df= train.copy()
df.shape
# Out:
# (391939, 23)

# %%
col_dic = {'ARI_CO':'도착국가',
            'ARI_PO':'도착항구명',
            'SHIP_TYPE_CATEGORY':'5대 선종으로 분류',
            'DIST':'정박지와 접안지 거리(km)',
            'ATA':'실제 정박 시각(H)',
            'ID':'선박식별 일련번호',
            'BREADTH':'선박 폭(m)',
            'BUILT':'선박 연령',
            'DEADWEIGHT':'선박 재화중량톤수(t)',
            'DEPTH':'선박 깊이(m)',
            'DRAUGHT':'흘수 높이(m)',
            'GT':'용적톤수 값',
            'LENGTH':'선박 길이(m)',
            'SHIPMANAGER':'선박 소유주',
            'FLAG':'선박 국적',
            'U_WIND':'풍향 u벡터(m/s)',
            'V_WIND':'풍향 v벡터(m/s)',
            'AIR_TEMPERATURE':'기온(C)',
            'BN':'보퍼트 풍력 계급',
            'ATA_LT':'현지 정박 시각(H)',
            'DUBAI':'해당일의 두바이유 값($)',
            'BRENT':'해당일의 브렌트유 값($)',
            'WTI':'해당일의 WTI 값($)',
            'BDI_ADJ':'조정된 벌크운임지수',
            'PORT_SIZE':'접안지 폴리곤 영역의 크기',
            'CI_HOUR':'대기시간(h)'}

# %%
df = df.rename(columns=col_dic)
df.head(1)
# Out:
#       SAMPLE_ID 도착국가 도착항구명 5대 선종으로 분류  정박지와 접안지 거리(km)       실제 정박 시각(H)  \
# 0  TRAIN_000000   SG  GIW5  Container        30.881018  2018-12-17 21:29
#
#   선박식별 일련번호  선박 폭(m)  선박 연령  선박 재화중량톤수(t)  ...  선박 길이(m)  선박 소유주   선박 국적  \
# 0   Z618338     30.0     24         24300  ...     180.0  CQSB78  Panama
#
#    풍향 u벡터(m/s) 풍향 v벡터(m/s) 기온(C)  보퍼트 풍력 계급  현지 정박 시각(H)  접안지 폴리곤 영역의 크기  \
# 0          NaN         NaN   NaN        NaN            5        0.002615
#
#    대기시간(h)
# 0     3.45
#
# [1 rows x 23 columns]

# %%
df.isnull().sum()
# Out:
# SAMPLE_ID               0
# 도착국가                    0
# 도착항구명                   0
# 5대 선종으로 분류              0
# 정박지와 접안지 거리(km)         0
# 실제 정박 시각(H)             0
# 선박식별 일련번호               0
# 선박 폭(m)                 1
# 선박 연령                   0
# 선박 재화중량톤수(t)            0
# 선박 깊이(m)                1
# 흘수 높이(m)                1
# 용적톤수 값                  0
# 선박 길이(m)                1
# 선박 소유주                  0
# 선박 국적                   0
# 풍향 u벡터(m/s)        163688
# 풍향 v벡터(m/s)        163688
# 기온(C)              164630
# 보퍼트 풍력 계급          163688
# 현지 정박 시각(H)             0
# 접안지 폴리곤 영역의 크기          0
# 대기시간(h)                 0
# dtype: int64

# %%
df.columns
# Out:
# Index(['SAMPLE_ID', '도착국가', '도착항구명', '5대 선종으로 분류', '정박지와 접안지 거리(km)',
#        '실제 정박 시각(H)', '선박식별 일련번호', '선박 폭(m)', '선박 연령', '선박 재화중량톤수(t)',
#        '선박 깊이(m)', '흘수 높이(m)', '용적톤수 값', '선박 길이(m)', '선박 소유주', '선박 국적',
#        '풍향 u벡터(m/s)', '풍향 v벡터(m/s)', '기온(C)', '보퍼트 풍력 계급', '현지 정박 시각(H)',
#        '접안지 폴리곤 영역의 크기', '대기시간(h)'],
#       dtype='object')

# %%
df_port_temp = df.groupby(['도착항구명'])['기온(C)'].mean()
len(df_port_temp)
# Out:
# 103

# %%
len(df['도착항구명'].unique())
# Out:
# 103

# %%
df_port_v = df.groupby(['도착항구명'])['풍향 v벡터(m/s)'].mean().to_dict()

# %%
df_port_u = df.groupby(['도착항구명'])['풍향 u벡터(m/s)'].mean().to_dict()
df_port_u
# Out:
# {'AIB7': -0.47914153132250575,
#  'AZU6': 0.3213166144200627,
#  'BAZ5': -0.7881471004243282,
#  'BGD2': 0.3820081511670989,
#  'BGX4': -1.2200467289719625,
#  'CEI5': 0.32887113951011715,
#  'CSP6': 0.19626168224299062,
#  'CXL1': 0.49565721649484534,
#  'DEJ2': 0.8673626373626373,
#  'DIN2': -0.15642857142857142,
#  'DMD4': 0.8986600719424461,
#  'EFG4': 0.3881777777777778,
#  'EIA2': 0.21008207934336523,
#  'EKP8': -0.6632751229353172,
#  'EUC8': -1.0508544875656138,
#  'EVL6': 1.0030357142857143,
#  'EVX2': 0.043576017130620995,
#  'FAV3': 1.3906511627906977,
#  'FCD5': 0.22423855496729989,
#  'FFM2': -0.9018734283319363,
#  'FTQ1': -2.1756249999999997,
#  'GIW5': -0.5275821515046697,
#  'GQJ7': 1.2752032520325203,
#  'GRQ5': 1.3012359550561796,
#  'HGH2': 1.0377045177045177,
#  'HYG5': 0.11353631694790901,
#  'HYV6': 1.0435081967213113,
#  'IEW6': -0.04717253317945759,
#  'IVU2': -5.505934718100891,
#  'JDG8': -1.1251574803149607,
#  'JEA6': -1.58,
#  'JEN5': 0.17463576158940397,
#  'JER7': 3.1546776929601354,
#  'JGL5': -0.923300395256917,
#  'JTD1': 0.4642432301740812,
#  'JWI3': -0.9966485630233084,
#  'KIU2': 0.20292709466811754,
#  'KSF1': -1.668681917211329,
#  'LHD1': 0.30517110266159697,
#  'LXJ7': -0.22140613586559535,
#  'MCG4': 0.7893478260869565,
#  'MIA8': 0.09821559392987965,
#  'MMW5': -0.26674443266171793,
#  'MOC5': 0.4608244680851064,
#  'NCU8': -3.042407899103883,
#  'NGG6': -0.8118767967145791,
#  'NNC2': 1.1808783783783785,
#  'NQO4': -1.155638786764706,
#  'OBZ3': 0.8196653796653797,
#  'OKM4': 0.9328035538005922,
#  'ONW1': -0.7973333333333332,
#  'OOV8': 0.4413353115727003,
#  'OZD2': -0.6777981651376146,
#  'PAF4': -3.1464809384164223,
#  'PBQ1': -0.8532558139534884,
#  'PDL4': 1.1804545454545454,
#  'PEL6': 0.15417004048582994,
#  'PPM2': -0.039398907103825126,
#  'PUF3': 0.8286296296296296,
#  'QEA4': 1.5786054827175209,
#  'QGL7': -1.7668181818181818,
#  'QGN3': -0.7748731884057971,
#  'QQW1': -0.6286887168660568,
#  'QRN3': -1.1891399229781772,
#  'QTU5': 0.555214626391097,
#  'QXE2': 0.36382716049382713,
#  'QYY1': 0.836331096196868,
#  'REJ1': 0.02441860465116279,
#  'RGT8': nan,
#  'RKA2': 0.7019956850053938,
#  'SLZ5': 0.9082696759259259,
#  'SPG1': 0.45165438165438165,
#  'SXD2': 0.320625,
#  'TBL3': 0.12957860615883307,
#  'TDA5': -0.5087849698299506,
#  'TMR7': 1.1188033220083051,
#  'TMW2': -5.6279960019990005,
#  'TXO3': -0.7214850882531955,
#  'TYY2': -1.0350828729281767,
#  'UEW5': 2.406184210526316,
#  'UIR7': 0.7937307032590052,
#  'UJM2': 2.24496215704825,
#  'UPI6': -0.12587209302325583,
#  'URD4': -0.03742372881355931,
#  'URE2': 0.4700179533213645,
#  'UVK6': 0.24076366030283078,
#  'VFD8': -1.63545,
#  'VXM8': 0.7072411729503291,
#  'VYJ1': 0.03367706237424547,
#  'WAF5': -1.3758103326256192,
#  'WEY7': 0.97347891243845,
#  'WHH4': 0.618574435514734,
#  'WXQ2': 0.22613125,
#  'XEO4': 0.12191919191919193,
#  'XGX5': -0.5649180327868852,
#  'XIU1': 1.0229222972972973,
#  'XVZ3': -2.471175572519084,
#  'XZF6': -1.8933333333333333,
#  'YDP4': 0.2990295119182747,
#  'YFK5': 0.4292156862745098,
#  'YRT6': -0.003005415162454877,
#  'ZAG4': 0.2500088313217545,
#  'ZME5': -0.6797368421052632}

# %%
df_port_class = df.groupby(['도착항구명'])['보퍼트 풍력 계급'].mean().to_dict()
df_port_class
# Out:
# {'AIB7': 3.879398509956303,
#  'AZU6': 1.6734200471166143,
#  'BAZ5': 1.860852024029703,
#  'BGD2': 1.9190505883771767,
#  'BGX4': 3.275843420945483,
#  'CEI5': 3.218859367518637,
#  'CSP6': 2.3092601659813083,
#  'CXL1': 2.9503313978221652,
#  'DEJ2': 3.585550719258242,
#  'DIN2': 0.9808889920714285,
#  'DMD4': 1.9078878996241007,
#  'EFG4': 2.2159008422933333,
#  'EIA2': 3.3125388304295487,
#  'EKP8': 3.690164287960661,
#  'EUC8': 3.2106850511949916,
#  'EVL6': 2.171185417615385,
#  'EVX2': 3.2224016834668094,
#  'FAV3': 3.5457608649348837,
#  'FCD5': 3.3726894823235756,
#  'FFM2': 2.4197171112171,
#  'FTQ1': 3.4027928285673075,
#  'GIW5': 2.014492625468888,
#  'GQJ7': 1.8344234060813007,
#  'GRQ5': 3.7139583369999998,
#  'HGH2': 2.2291944346788766,
#  'HYG5': 1.8339143892386893,
#  'HYV6': 1.8665486475770492,
#  'IEW6': 2.8010667328643972,
#  'IVU2': 3.587617332740356,
#  'JDG8': 2.586190362066929,
#  'JEA6': 1.5715675432424243,
#  'JEN5': 3.2148728277220435,
#  'JER7': 3.6515399254071244,
#  'JGL5': 1.6542038958636365,
#  'JTD1': 3.4041502478609766,
#  'JWI3': 2.987039018660632,
#  'KIU2': 2.6736404779499456,
#  'KSF1': 2.328279467880719,
#  'LHD1': 2.3634311933612167,
#  'LXJ7': 2.119693936869613,
#  'MCG4': 2.879925489227425,
#  'MIA8': 2.483051606742282,
#  'MMW5': 1.8020099186044538,
#  'MOC5': 3.5493728658776598,
#  'NCU8': 3.8011135013333885,
#  'NGG6': 2.2441098099555097,
#  'NNC2': 2.9880774445108105,
#  'NQO4': 1.8426743379545039,
#  'OBZ3': 1.5950622103655083,
#  'OKM4': 1.70262207923001,
#  'ONW1': 1.5444835558,
#  'OOV8': 1.6710078697091988,
#  'OZD2': 1.9002143444701833,
#  'PAF4': 3.49253456586217,
#  'PBQ1': 3.9724072477774084,
#  'PDL4': 1.8266552861060605,
#  'PEL6': 2.843762802962213,
#  'PPM2': 1.0259647881493625,
#  'PUF3': 1.9998992808185183,
#  'QEA4': 3.3304235107103697,
#  'QGL7': 2.0262249654107745,
#  'QGN3': 3.3000491196349637,
#  'QQW1': 2.2382918212413796,
#  'QRN3': 3.19779861426059,
#  'QTU5': 2.6148883928744038,
#  'QXE2': 1.9203478178518518,
#  'QYY1': 2.1575860314332926,
#  'REJ1': 1.2527711540268336,
#  'RGT8': nan,
#  'RKA2': 2.1852190667912623,
#  'SLZ5': 3.5731698631487268,
#  'SPG1': 3.7304248399352993,
#  'SXD2': 2.4115416909875003,
#  'TBL3': 2.380319319967585,
#  'TDA5': 2.1103977680617114,
#  'TMR7': 3.1276628403586257,
#  'TMW2': 3.7359053668350826,
#  'TXO3': 3.3124933727808883,
#  'TYY2': 2.415783338392265,
#  'UEW5': 3.9405419064605263,
#  'UIR7': 2.362022894397084,
#  'UJM2': 3.1029328078150424,
#  'UPI6': 3.3660560423720933,
#  'URD4': 2.1238157495864405,
#  'URE2': 1.5787834832881509,
#  'UVK6': 2.3116897283759053,
#  'VFD8': 3.619886677076429,
#  'VXM8': 2.5056652366588867,
#  'VYJ1': 2.8244593183003017,
#  'WAF5': 2.337510707482661,
#  'WEY7': 3.16430917416185,
#  'WHH4': 3.2354015814094907,
#  'WXQ2': 3.5620222081987496,
#  'XEO4': 0.38306217156228956,
#  'XGX5': 1.640608916442623,
#  'XIU1': 1.9044144953952702,
#  'XVZ3': 2.887799021211705,
#  'XZF6': 3.0632495824615384,
#  'YDP4': 3.507177622755959,
#  'YFK5': 2.0851426335735295,
#  'YRT6': 2.877114306594991,
#  'ZAG4': 1.8397308726580806,
#  'ZME5': 3.2361793050263157}

# %%
df.loc[df['도착항구명']=='RGT8']
# Out:
#            SAMPLE_ID 도착국가 도착항구명 5대 선종으로 분류  정박지와 접안지 거리(km)       실제 정박 시각(H)  \
# 142387  TRAIN_142387   CN  RGT8       Bulk         0.000000  2017-05-29 13:07
# 148686  TRAIN_148686   CN  RGT8       Bulk        31.302818  2017-11-20 10:49
# 249057  TRAIN_249057   CN  RGT8       Bulk         0.000000   2017-08-15 3:27
# 262052  TRAIN_262052   CN  RGT8       Bulk        32.857388  2017-07-27 15:24
# 337771  TRAIN_337771   CN  RGT8       Bulk         0.000000   2017-10-30 6:04
# 360066  TRAIN_360066   CN  RGT8       Bulk         0.000000  2017-03-30 10:34
#
#        선박식별 일련번호  선박 폭(m)  선박 연령  선박 재화중량톤수(t)  ...  선박 길이(m)  선박 소유주  \
# 142387   G463522     10.0     32          3680  ...      80.0  SQLZ13
# 148686   I512572     10.0     19          3280  ...      80.0  AOQV31
# 249057   Q341646     10.0     20          2860  ...      80.0  RPUJ77
# 262052   T422815     10.0     34          3090  ...      90.0  SLHK46
# 337771   G512525     20.0     13          5150  ...     100.0  VYES16
# 360066   X125168     10.0     17          2800  ...      80.0  VKVS56
#
#                               선박 국적  풍향 u벡터(m/s) 풍향 v벡터(m/s) 기온(C)  보퍼트 풍력 계급  \
# 142387                 Korea, North          NaN         NaN   NaN        NaN
# 148686                     Barbados          NaN         NaN   NaN        NaN
# 249057                        Palau          NaN         NaN   NaN        NaN
# 262052                     Honduras          NaN         NaN   NaN        NaN
# 337771  China, People's Republic Of          NaN         NaN   NaN        NaN
# 360066                       Belize          NaN         NaN   NaN        NaN
#
#         현지 정박 시각(H)  접안지 폴리곤 영역의 크기    대기시간(h)
# 142387           21        0.000026   0.000000
# 148686           18        0.000026  37.106111
# 249057           11        0.000026   0.000000
# 262052           23        0.000026  21.553889
# 337771           14        0.000026   0.000000
# 360066           18        0.000026   0.000000
#
# [6 rows x 23 columns]

# %%
df = df[df.도착항구명 != 'RGT8']
df.shape
# Out:
# (391933, 23)

# %%
df.boxplot()
# Out:
# <Axes: >
