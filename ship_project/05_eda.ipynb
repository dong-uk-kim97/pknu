# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['axes.unicode_minus'] = False

sns.set_style('whitegrid')
sns.set('notebook',
        font='Malgun Gothic',
        rc={"axes.unicode_minus":False},
        style='whitegrid')

# %%
train = pd.read_csv('./data/train.csv').drop(columns='SAMPLE_ID')
df = train.copy()
df
# Out:
#        ARI_CO ARI_PO SHIP_TYPE_CATEGORY       DIST               ATA       ID  \
# 0          SG   GIW5          Container  30.881018  2018-12-17 21:29  Z618338
# 1          IN   UJM2               Bulk   0.000000   2014-09-23 6:59  X886125
# 2          CN   EUC8          Container   0.000000  2015-02-03 22:00  T674582
# 3          JP   ZAG4          Container   0.000000   2020-01-17 4:02  Y847238
# 4          SG   GIW5          Container  27.037650   2020-01-26 7:51  A872328
# ...       ...    ...                ...        ...               ...      ...
# 391934     JP   QYY1          Container   0.000000   2017-06-06 5:02  Y375615
# 391935     SG   GIW5               Bulk   5.884603   2019-10-16 0:36  K635567
# 391936     US   QGN3               Bulk  70.660241  2021-03-23 22:35  J284147
# 391937     TW   JWI3          Container   9.448179   2015-01-08 7:15  J644215
# 391938     TW   JWI3          Container   0.000000  2015-06-08 23:30  D123358
#
#         BREADTH  BUILT  DEADWEIGHT  DEPTH  ...  LENGTH  SHIPMANAGER  \
# 0          30.0     24       24300   10.0  ...   180.0       CQSB78
# 1          30.0     13       35900   10.0  ...   180.0       SPNO34
# 2          50.0     12      146000   30.0  ...   370.0       FNPK22
# 3          20.0     18        6910   10.0  ...   120.0       PBZV77
# 4          50.0     10      116000   20.0  ...   300.0       GUCE76
# ...         ...    ...         ...    ...  ...     ...          ...
# 391934     20.0     27        6820   10.0  ...   110.0       KEJZ24
# 391935     10.0     12        3160   10.0  ...    80.0       JLTM64
# 391936     30.0      8       60300   20.0  ...   200.0       YERJ68
# 391937     30.0     29       23800   10.0  ...   170.0       HCZK58
# 391938     30.0     15       50600   20.0  ...   260.0       GRJG55
#
#                                FLAG U_WIND V_WIND  AIR_TEMPERATURE        BN  \
# 0                            Panama    NaN    NaN              NaN       NaN
# 1                  Marshall Islands    NaN    NaN              NaN       NaN
# 2                             Malta    NaN    NaN              NaN       NaN
# 3                           Bahamas  -3.18  -1.61              6.7  2.629350
# 4                           Liberia  -0.33  -3.28             25.6  2.495953
# ...                             ...    ...    ...              ...       ...
# 391934  China, People's Republic Of    NaN    NaN              NaN       NaN
# 391935                      Vietnam  -0.66   0.97             27.3  1.253491
# 391936                    Singapore  -3.44   7.99             21.1  4.766257
# 391937                      Comoros    NaN    NaN              NaN       NaN
# 391938             Hong Kong, China    NaN    NaN              NaN       NaN
#
#         ATA_LT  PORT_SIZE     CI_HOUR
# 0            5   0.002615    3.450000
# 1           12   0.000217    0.000000
# 2            6   0.001614    0.000000
# 3           13   0.000356    0.000000
# 4           15   0.002615  253.554444
# ...        ...        ...         ...
# 391934      14   0.000552    0.000000
# 391935       8   0.002615  144.061389
# 391936      18   0.000155   41.482222
# 391937      15   0.000990    7.485278
# 391938       7   0.000990    0.000000
#
# [391939 rows x 22 columns]

# %%
plt.figure(figsize=(8,8))
sns.lineplot(data=df, x='ATA_LT', y='CI_HOUR',hue='SHIP_TYPE_CATEGORY')
plt.legend(loc='best',fontsize='small')
plt.show();

# %%
sns.histplot(x='BUILT',data=df)
# Out:
# <Axes: xlabel='BUILT', ylabel='Count'>

# %%
# Out:
# array([24, 13, 12, 18, 10,  7, 30, 11, 23, 15,  9, 17, 27, 14, 16, 19,  8,
#         6, 25, 22,  3,  5, 28, 26, 31, 20, 21,  4, 29, 34, 35, 36, 38,  2,
#         1, 39, 33, 32, 42, 40, 37, 43, 47, 71, 41,  0, 56, 44, 48, 45, 65,
#        49, 52, 64, 50, 51, 46, 59, 53, 54, 55, 80, 57, 70], dtype=int64)
